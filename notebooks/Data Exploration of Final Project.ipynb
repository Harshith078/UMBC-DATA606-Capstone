# %% [markdown]
# ## Loading dataset

# %%
import json

# Specify the path to your JSON file
file_path = "amazon_uk_shoes_dataset.json"

# Open the JSON file and load its contents
with open(file_path, "r") as file:
    data = json.load(file)

# %%
data
# Out:
# [{'url': 'https://www.amazon.co.uk/dp/B08BLP231K',
#   'title': 'Geox Jr Sandal Strada B Fisherman, Brown Red, 2.5 UK Child',
#   'asin': 'B08BLP231K',
#   'price': '£50.00',
#   'brand': 'Visit the Geox Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n31.2 x 21.4 x 11.4 cm; 820 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n22 Jun. 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nGeox\n\n\nASIN\n\u200f\n:\n\u200e\n\nB08BLP231K\n\n\nItem model number\n\u200f\n:\n\u200e\n\nJ1524B02214\n\n\nCountry of origin\n\u200f\n:\n\u200e\n\nVietnam\n\n\nDepartment\n\u200f\n:\n\u200e\n\nBoy's",
#   'breadcrumbs': "Shoes/Boys' Shoes/Sandals",
#   'images_list': ['https://m.media-amazon.com/images/I/41OuvqjhaqL.jpg',
#    'https://m.media-amazon.com/images/I/51zt+Bb48FL.jpg',
#    'https://m.media-amazon.com/images/I/51EXdVtkpAL.jpg',
#    'https://m.media-amazon.com/images/I/41u3T2DxWkL.jpg',
#    'https://m.media-amazon.com/images/I/41ZOt3pgbSL.jpg',
#    'https://m.media-amazon.com/images/I/41FEYlXQNFL.jpg',
#    'https://m.media-amazon.com/images/I/41Nqt4ULBUL.jpg'],
#   'features': [{'Outer Material': 'Synthetic'},
#    {'Inner Material': 'Synthetic'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Strap'},
#    {'Heel Height': '2 centimetres'},
#    {'Heel Type': 'Flat'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08N587YZ9',
#   'title': "Fila Women's Oakmont Tr Sneaker",
#   'asin': 'B08N587YZ9',
#   'price': '£49.57 - £234.95',
#   'brand': 'Fila',
#   'product_details': "Product Dimensions\n\u200f\n:\n\u200e\n\n32.51 x 21.84 x 12.19 cm; 952.54 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n6 Jun. 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nFila\n\n\nASIN\n\u200f\n:\n\u200e\n\nB089RQLYNW\n\n\nItem model number\n\u200f\n:\n\u200e\n\n5JM00948-990\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/416fCMuxwLL.jpg',
#    'https://m.media-amazon.com/images/I/51mkH58Ym8L.jpg',
#    'https://m.media-amazon.com/images/I/51FOdSMTzHL.jpg',
#    'https://m.media-amazon.com/images/I/41nDJ-+mwBL.jpg',
#    'https://m.media-amazon.com/images/I/41EEIOcPNKL.jpg',
#    'https://m.media-amazon.com/images/I/416y8+Qzp2L.jpg',
#    'https://m.media-amazon.com/images/I/41STmbB8njL.jpg'],
#   'features': [{'Outer Material': 'fabric'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Type': 'No Heel'},
#    {'Shoe Width': 'medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B0918K4H1W',
#   'title': "Gabor Rollingsoft Trainers in Plus Sizes Beige 66.938.30 Large Women's Shoes",
#   'asin': 'B0918K4H1W',
#   'price': None,
#   'brand': 'Gabor',
#   'product_details': "Is Discontinued By Manufacturer\n\u200f\n:\n\u200e\n\nNo\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n26 April 2021\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nrollingsoft\n\n\nASIN\n\u200f\n:\n\u200e\n\nB0918K4H1W\n\n\nItem model number\n\u200f\n:\n\u200e\n\n66.938-30\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/31GuoIF6FmL.jpg',
#    'https://m.media-amazon.com/images/I/317PRDRbPRL.jpg',
#    'https://m.media-amazon.com/images/I/31WCZ3IunBL.jpg',
#    'https://m.media-amazon.com/images/I/31GzfcPERSL.jpg',
#    'https://m.media-amazon.com/images/I/31HTleJH3bL.jpg',
#    'https://m.media-amazon.com/images/I/31lkVAeCMeL.jpg',
#    'https://m.media-amazon.com/images/I/412zP242i+L.jpg'],
#   'features': [{'Outer Material': 'Leather'},
#    {'Sole': 'Leather'},
#    {'Closure': 'Lace-Up'},
#    {'Shoe Width': 'Schmal'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07KMB98CG',
#   'title': "Merrell Women'S Bare Access Xtr Trail Running Shoes",
#   'asin': 'B07KMB98CG',
#   'price': '£67.00 - £182.44',
#   'brand': 'Visit the Merrell Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n28.96 x 19.81 x 10.16 cm; 544 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n20 Jan. 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nMerrell\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07VFXC6T4\n\n\nItem model number\n\u200f\n:\n\u200e\n\nJ066420\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Sports & Outdoor Shoes/Running Shoes/Trail Running Shoes",
#   'images_list': ['https://m.media-amazon.com/images/I/51bLpccQMkL.jpg',
#    'https://m.media-amazon.com/images/I/51X3qFZUIxL.jpg',
#    'https://m.media-amazon.com/images/I/51MQseoK7RL.jpg',
#    'https://m.media-amazon.com/images/I/41aDt5XRu8L.jpg',
#    'https://m.media-amazon.com/images/I/41us9YGUh2L.jpg',
#    'https://m.media-amazon.com/images/I/41qdx8YsT9L.jpg',
#    'https://m.media-amazon.com/images/I/41d-HO03K4L.jpg'],
#   'features': [{'Outer Material': 'Synthetic'},
#    {'Inner Material': 'Manmade'},
#    {'Sole': 'Synthetic'},
#    {'Closure': 'Lace-Up'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08CN3S1ZK',
#   'title': "Desigual Women's Shoes_Runner_cmofl Sneakers Woman",
#   'asin': 'B08CN3S1ZK',
#   'price': '£38.96 - £81.10',
#   'brand': 'Desigual',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n34.6 x 21.8 x 11.6 cm; 500 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n13 July 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nDesigual\n\n\nASIN\n\u200f\n:\n\u200e\n\nB08CN4MH5P\n\n\nItem model number\n\u200f\n:\n\u200e\n\n9019\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/41nMmmxX-oL.jpg',
#    'https://m.media-amazon.com/images/I/413yrw6izSL.jpg',
#    'https://m.media-amazon.com/images/I/51GYDvFInuL.jpg',
#    'https://m.media-amazon.com/images/I/41XLBSGfhpL.jpg',
#    'https://m.media-amazon.com/images/I/41ce6h+LkfL.jpg',
#    'https://m.media-amazon.com/images/I/410n1HdmoWL.jpg',
#    'https://m.media-amazon.com/images/I/41Sw5OMEECL.jpg'],
#   'features': [{'Outer Material': 'Polyester'},
#    {'Inner Material': 'Synthetic'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Type': 'Flat'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07KJX15DV',
#   'title': "Aquatalia Men's Adamo Dress Calf Penny Loafer",
#   'asin': 'B07KJX15DV',
#   'price': '£161.63 - £202.04',
#   'brand': 'Aquatalia',
#   'product_details': "Product Dimensions\n\u200f\n:\n\u200e\n\n24.13 x 15.24 x 10.16 cm; 402.56 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n14 Jan. 2019\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nAquatalia\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07KJX15DV\n\n\nItem model number\n\u200f\n:\n\u200e\n\n34M0642-COG\n\n\nDepartment\n\u200f\n:\n\u200e\n\nMen's",
#   'breadcrumbs': "Shoes/Men's Shoes/Loafers & Moccasins",
#   'images_list': ['https://m.media-amazon.com/images/I/31Q2dvpJryL.jpg',
#    'https://m.media-amazon.com/images/I/41uTxM9VBHL.jpg',
#    'https://m.media-amazon.com/images/I/41ynI5DMZnL.jpg',
#    'https://m.media-amazon.com/images/I/21WOABMNIAL.jpg',
#    'https://m.media-amazon.com/images/I/319g5-RTshL.jpg',
#    'https://m.media-amazon.com/images/I/317ji9LWSKL.jpg',
#    'https://m.media-amazon.com/images/I/31aJwmaFbSL.jpg'],
#   'features': [{'Sole': 'Rubber'},
#    {'Closure': 'Pull On'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B089GYT1HP',
#   'title': 'Womens Convertible Slip-on, Tan, 12',
#   'asin': 'B089GYT1HP',
#   'price': '£52.82',
#   'brand': 'Unknown',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n32 x 18.29 x 12.7 cm; 658 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n14 Jun. 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nSpenco\n\n\nASIN\n\u200f\n:\n\u200e\n\nB089GYT1HP\n\n\nItem model number\n\u200f\n:\n\u200e\n\nSP1010TAN120\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/31cusYt00VL.jpg',
#    'https://m.media-amazon.com/images/I/419AtRU0DNL.jpg',
#    'https://m.media-amazon.com/images/I/41N7jkd4zHL.jpg',
#    'https://m.media-amazon.com/images/I/31zkJ8SGGDL.jpg',
#    'https://m.media-amazon.com/images/I/31PP+ISFQgL.jpg',
#    'https://m.media-amazon.com/images/I/31Shj6UpzDL.jpg',
#    'https://m.media-amazon.com/images/I/41iLkwMwMFL.jpg'],
#   'features': [{'Sole': 'Rubber'},
#    {'Closure': 'Pull On'},
#    {'Heel Type': 'Low'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B01614251K',
#   'title': "Kappa Delhi Footwear Unisex, Mesh, Women's Low-Top Sneakers",
#   'asin': 'B01614251K',
#   'price': '£46.18',
#   'brand': 'Visit the Kappa Store',
#   'product_details': "Date First Available\n\u200f\n:\n\u200e\n\n30 Dec. 2015\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nKappa\n\n\nASIN\n\u200f\n:\n\u200e\n\nB01614FQP2\n\n\nItem model number\n\u200f\n:\n\u200e\n\n242105\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/41MfJGQsSBL.jpg',
#    'https://m.media-amazon.com/images/I/519qDn3yq-L.jpg',
#    'https://m.media-amazon.com/images/I/41rCXl8bBcL.jpg',
#    'https://m.media-amazon.com/images/I/31Acajc-xYL.jpg',
#    'https://m.media-amazon.com/images/I/413wcLbldIL.jpg',
#    'https://m.media-amazon.com/images/I/41Pi0Vfo+QL.jpg',
#    'https://m.media-amazon.com/images/I/41e05YNjCrL.jpg'],
#   'features': [{'Outer Material': 'Synthetic'},
#    {'Inner Material': 'Mesh'},
#    {'Sole': 'Manmade'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Type': 'Flat'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07MJ4DRRZ',
#   'title': "Naturalizer Women's Cairo 4 Sneaker, Medium",
#   'asin': 'B07MJ4DRRZ',
#   'price': '£41.66 - £73.51',
#   'brand': 'Naturalizer',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n32.76 x 18.28 x 11.17 cm; 317.51 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n12 Mar. 2019\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nNaturalizer\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07MLPQH1Y\n\n\nItem model number\n\u200f\n:\n\u200e\n\nG0658F1650\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/31B+IfyybEL.jpg',
#    'https://m.media-amazon.com/images/I/41nARY0TYlL.jpg',
#    'https://m.media-amazon.com/images/I/41MhfjmosPL.jpg',
#    'https://m.media-amazon.com/images/I/31Sfx9bndiL.jpg',
#    'https://m.media-amazon.com/images/I/31k+FmRm1hL.jpg',
#    'https://m.media-amazon.com/images/I/31QdigB4GPL.jpg',
#    'https://m.media-amazon.com/images/I/41S6ADRTfyL.jpg'],
#   'features': [{'Sole': 'Synthetic'},
#    {'Closure': 'Lace-Up'},
#    {'Shoe Width': 'M'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07GX8GPJN',
#   'title': 'Rockport - Womens Cobb Hill Hattie Hi Cuff Platform Shoe',
#   'asin': 'B07GX8GPJN',
#   'price': '£120.35 - £130.73',
#   'brand': 'Visit the Rockport Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n30.48 x 20.83 x 11.18 cm; 739 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n7 April 2020\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07GX5Y7QP\n\n\nItem model number\n\u200f\n:\n\u200e\n\nCH4626\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Court Shoes",
#   'images_list': ['https://m.media-amazon.com/images/I/51H4VpBqujL.jpg'],
#   'features': [{'Outer Material': 'Synthetic'},
#    {'Sole': 'Leather, Ethylene Vinyl Acetate'},
#    {'Closure': 'Buckle'},
#    {'Heel Type': 'Wedge'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B012DS5U2Y',
#   'title': "Reebok Men's NPC Ii Fashion Sneaker",
#   'asin': 'B012DS5U2Y',
#   'price': '£47.00 - £156.93',
#   'brand': 'Visit the Reebok Store',
#   'product_details': "Is Discontinued By Manufacturer\n\u200f\n:\n\u200e\n\nNo\n\n\nProduct Dimensions\n\u200f\n:\n\u200e\n\n1 x 1 x 1 cm; 340.19 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n8 Feb. 2016\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nReebok\n\n\nASIN\n\u200f\n:\n\u200e\n\nB00XJYHWU0\n\n\nItem model number\n\u200f\n:\n\u200e\n\n889131332620\n\n\nDepartment\n\u200f\n:\n\u200e\n\nBoy's",
#   'breadcrumbs': "Shoes/Men's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/31Q5ITz9A1L.jpg',
#    'https://m.media-amazon.com/images/I/31zTqnl8B1L.jpg',
#    'https://m.media-amazon.com/images/I/31cJeqWHkXL.jpg',
#    'https://m.media-amazon.com/images/I/31VChOZlUvL.jpg',
#    'https://m.media-amazon.com/images/I/31tZwWe46cL.jpg',
#    'https://m.media-amazon.com/images/I/312gwJ-AfwL.jpg',
#    'https://m.media-amazon.com/images/I/31aftLNUgNL.jpg'],
#   'features': [{'Outer Material': 'Leather'},
#    {'Inner Material': 'Manmade'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Height': '1 centimetres'},
#    {'Heel Type': 'Flat'},
#    {'Shoe Width': 'Normal'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08D3F9JQY',
#   'title': "adidas Women's Superstar Bold W Gymnastics Shoe",
#   'asin': 'B08D3F9JQY',
#   'price': '£85.00 - £93.61',
#   'brand': 'Visit the adidas Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n28.8 x 19.2 x 10.8 cm; 880 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n21 Sept. 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nAdidas\n\n\nASIN\n\u200f\n:\n\u200e\n\nB089RRHNZP\n\n\nItem model number\n\u200f\n:\n\u200e\n\nFV3334\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/31iEsAXEKWL.jpg',
#    'https://m.media-amazon.com/images/I/31ebhXvIqUL.jpg',
#    'https://m.media-amazon.com/images/I/31srq7sW-gL.jpg',
#    'https://m.media-amazon.com/images/I/31yVdG+11LL.jpg',
#    'https://m.media-amazon.com/images/I/3181dSfKKHL.jpg'],
#   'features': [{'Outer Material': 'Smooth Leather'},
#    {'Inner Material': 'Textile'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Type': 'No Heel'},
#    {'Material Composition': 'Leather upper, textile lining, rubber outsole'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B01GRUZWAO',
#   'title': "Geox Women's D Sfinge a Fashion Sneaker",
#   'asin': 'B01GRUZWAO',
#   'price': '£64.95 - £117.00',
#   'brand': 'Visit the Geox Store',
#   'product_details': "Is Discontinued By Manufacturer\n\u200f\n:\n\u200e\n\nNo\n\n\nPackage Dimensions\n\u200f\n:\n\u200e\n\n31.2 x 22.6 x 11 cm; 340.19 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n8 Aug. 2016\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nGeox\n\n\nASIN\n\u200f\n:\n\u200e\n\nB01C5171VC\n\n\nItem model number\n\u200f\n:\n\u200e\n\nD642NA\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/41nClsGThtL.jpg',
#    'https://m.media-amazon.com/images/I/41wk9QjiMnL.jpg',
#    'https://m.media-amazon.com/images/I/41BPdM1ttRL.jpg',
#    'https://m.media-amazon.com/images/I/41bb40A9iYL.jpg',
#    'https://m.media-amazon.com/images/I/41u0DuohyDL.jpg',
#    'https://m.media-amazon.com/images/I/41wZ7aDasSL.jpg',
#    'https://m.media-amazon.com/images/I/41qjIMKAX+L.jpg'],
#   'features': [{'Outer Material': 'Leather'},
#    {'Inner Material': 'Mesh'},
#    {'Sole': 'Ethylene Vinyl Acetate'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Height': '3.5 centimetres'},
#    {'Heel Type': 'Flat'},
#    {'Fit Type': 'Bear in mind that Geox shoes have a comfortable fit, therefore we recommend choosing half a size smaller than your usual size'},
#    {'Shoe Width': 'Medium womens_us'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07SQ5MLXZ',
#   'title': "K-Swiss Men's Clean Court Ii CMF Low-Top Sneakers",
#   'asin': 'B07SQ5MLXZ',
#   'price': '£20.99 - £67.57',
#   'brand': 'K-Swiss',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n30.48 x 21.08 x 11.68 cm; 960 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n6 July 2019\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nK-Swiss\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07TLNCJJR\n\n\nItem model number\n\u200f\n:\n\u200e\n\nK06347\n\n\nDepartment\n\u200f\n:\n\u200e\n\nMen's",
#   'breadcrumbs': "Shoes/Men's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/31TbwQNbqTL.jpg',
#    'https://m.media-amazon.com/images/I/312ugppuUQL.jpg',
#    'https://m.media-amazon.com/images/I/315Hd+zudEL.jpg',
#    'https://m.media-amazon.com/images/I/31EN035Dx1L.jpg',
#    'https://m.media-amazon.com/images/I/31nQDiC785L.jpg',
#    'https://m.media-amazon.com/images/I/31SkaYKTSiL.jpg',
#    'https://m.media-amazon.com/images/I/31dF8pmbJSL.jpg'],
#   'features': [{'Outer Material': 'Leather'},
#    {'Inner Material': 'Synthetic Fur'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B00LIHRNQI',
#   'title': 'Volcom Mens Sub Zero Boot Winter',
#   'asin': 'B00LIHRNQI',
#   'price': '£65.11 - £238.10',
#   'brand': 'Visit the Volcom Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n36.3 x 26.48 x 12.36 cm; 453.59 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n14 Jan. 2019\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nVolcom\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07MF9VCPQ\n\n\nItem model number\n\u200f\n:\n\u200e\n\nV4011515\n\n\nDepartment\n\u200f\n:\n\u200e\n\nMen's",
#   'breadcrumbs': "Shoes/Men's Shoes/Boots",
#   'images_list': ['https://m.media-amazon.com/images/I/41TcKadAqZL.jpg',
#    'https://m.media-amazon.com/images/I/41dWg0GyQuL.jpg',
#    'https://m.media-amazon.com/images/I/416vBj9KjeL.jpg',
#    'https://m.media-amazon.com/images/I/41yOvHyIO-L.jpg',
#    'https://m.media-amazon.com/images/I/31jgngm5seL.jpg',
#    'https://m.media-amazon.com/images/I/411YkOaHu9L.jpg',
#    'https://m.media-amazon.com/images/I/41M9cYZEGlL.jpg'],
#   'features': [{'Outer Material': 'Leather'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07H3XFPR9',
#   'title': 'ASICS Mens Gel-Ziruss 2 Running Shoes Carbon/Black',
#   'asin': 'B07H3XFPR9',
#   'price': '£99.79 - £124.99',
#   'brand': 'ASICS',
#   'product_details': "Product Dimensions\n\u200f\n:\n\u200e\n\n25.25 x 9 x 7.8 cm; 330 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n10 Dec. 2019\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nAsics\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07G84GMTL\n\n\nItem model number\n\u200f\n:\n\u200e\n\n1011A011.020\n\n\nDepartment\n\u200f\n:\n\u200e\n\nMen's",
#   'breadcrumbs': "Shoes/Men's Shoes/Fashion & Athletic Trainers/Sports & Outdoor Shoes/Running Shoes/Road Running Shoes",
#   'images_list': ['https://m.media-amazon.com/images/I/419SXtgq6EL.jpg',
#    'https://m.media-amazon.com/images/I/51znFjH+w1L.jpg',
#    'https://m.media-amazon.com/images/I/51MoaCTJ6cL.jpg',
#    'https://m.media-amazon.com/images/I/413etqCs0LL.jpg',
#    'https://m.media-amazon.com/images/I/4180U+paIJL.jpg',
#    'https://m.media-amazon.com/images/I/4183Ca27wvL.jpg',
#    'https://m.media-amazon.com/images/I/51MFLeT+aCL.jpg'],
#   'features': [{'Outer Material': 'Synthetic'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07KQKYZYR',
#   'title': "bugatti Women's 432636065969 Low-Top Sneakers",
#   'asin': 'B07KQKYZYR',
#   'price': '£28.77 - £62.87',
#   'brand': 'bugatti',
#   'product_details': "Is Discontinued By Manufacturer\n\u200f\n:\n\u200e\n\nNo\n\n\nPackage Dimensions\n\u200f\n:\n\u200e\n\n32.4 x 20 x 10.4 cm; 929.86 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n4 Dec. 2018\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nBugatti\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07KQKYZYR\n\n\nItem model number\n\u200f\n:\n\u200e\n\n4.32636E+11\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/41exUG2FL5L.jpg',
#    'https://m.media-amazon.com/images/I/41StjshFK0L.jpg',
#    'https://m.media-amazon.com/images/I/41ggTW58phL.jpg',
#    'https://m.media-amazon.com/images/I/319IwX8smdL.jpg',
#    'https://m.media-amazon.com/images/I/31cVvjVBORL.jpg',
#    'https://m.media-amazon.com/images/I/31ziXpu7AtL.jpg',
#    'https://m.media-amazon.com/images/I/41x89YYyJKL.jpg'],
#   'features': [{'Outer Material': 'Synthetic'},
#    {'Inner Material': 'Textile'},
#    {'Sole': 'Ethylene Vinyl Acetate'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Type': 'Flat'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08HJJ5N7R',
#   'title': "Pablosky Girl's 495000 Sandal",
#   'asin': 'B08HJJ5N7R',
#   'price': '£25.76 - £36.69',
#   'brand': 'Pablosky',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n23 x 16 x 8 cm; 347 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n4 Sept. 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nPablosky\n\n\nASIN\n\u200f\n:\n\u200e\n\nB08HJM8WSS\n\n\nItem model number\n\u200f\n:\n\u200e\n\n495000\n\n\nDepartment\n\u200f\n:\n\u200e\n\nGirl's",
#   'breadcrumbs': "Shoes/Girls' Shoes/Sandals",
#   'images_list': ['https://m.media-amazon.com/images/I/31lTfKx5r0L.jpg',
#    'https://m.media-amazon.com/images/I/31AJQc5sE9L.jpg',
#    'https://m.media-amazon.com/images/I/31fUSsDPl+L.jpg',
#    'https://m.media-amazon.com/images/I/31MnM8uWBUL.jpg',
#    'https://m.media-amazon.com/images/I/31IHqiry2JL.jpg'],
#   'features': [{'Outer Material': 'Leather'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Hook & Loop'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08635QDSF',
#   'title': 'HROYL Girls Dance Shoes Satin Latin/Chacha/Samba/Modern/Jazz Dance Shoes Ballroom 206',
#   'asin': 'B08635QDSF',
#   'price': '£25.99 - £28.99',
#   'brand': 'Visit the HROYL Store',
#   'product_details': "Is Discontinued By Manufacturer\n\u200f\n:\n\u200e\n\nNo\n\n\nProduct Dimensions\n\u200f\n:\n\u200e\n\n17.4 x 6.4 x 10 cm; 145.15 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n7 Mar. 2017\n\n\nASIN\n\u200f\n:\n\u200e\n\nB01J76Z3KE\n\n\nItem model number\n\u200f\n:\n\u200e\n\nI-206-Black-25\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Sports & Outdoor Shoes/Dance Shoes",
#   'images_list': ['https://m.media-amazon.com/images/I/41u3nswtlAL.jpg',
#    'https://m.media-amazon.com/images/I/41+6R69avQL.jpg',
#    'https://m.media-amazon.com/images/I/51ZZf46pd2L.jpg',
#    'https://m.media-amazon.com/images/I/511Wct8kR9L.jpg',
#    'https://m.media-amazon.com/images/I/51MuvpcOhOL.jpg',
#    'https://m.media-amazon.com/images/I/51-7HmsLJLL.jpg',
#    'https://m.media-amazon.com/images/I/51BgT0jdDTL.jpg'],
#   'features': [{'❤️ Comfortable': 'The angle between the toe and the bottom is 15 degrees, which makes the dance movement easier to move forward or backward.Make the shoes comfort and flexibility.'},
#    {'Outer Material': 'Satin'},
#    {'Inner Material': 'Manmade'},
#    {'Sole': 'Synthetic'},
#    {'Closure': 'Buckle'},
#    {'Heel Height': '3.5 centimetres'},
#    {'Heel Type': 'Block'},
#    {'Material Composition': 'satin & gliter leather'},
#    {'Shaft Diameter': 'Medium'},
#    {'Shoe Width': 'Normal'},
#    {'❤️ SOFT LIGHTWEIGHT': 'Super lightweight and flexible, make you feel great freedom and comfortable in wearing, keep your amazing dancing..'},
#    {'❤️ OCCASION': 'indoor/outdoor ballroom dance such as salsa, quickstep, latin, waltz, foxtrot, rumba, cha cha, swing, disco, samba, jive,tango or some other special occasion such as wedding ,party or dance training center ,etc. .'},
#    {'❤️ SIZE TIP': 'Dance shoes are different from ordinary sports shoes. It needs high comfort, Please measure the length and width of your feet before purchase , then refer to our size chart for shopping. If your feet is a little wide please choose a bigger size..'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B084GB1DS3',
#   'title': "MILLET Unisex's Hike Up Mid GTX Slouch Boots",
#   'asin': 'B084GB1DS3',
#   'price': '£108.49 - £143.40',
#   'brand': 'Visit the MILLET Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n35 x 25.6 x 12.2 cm; 1.22 Kilograms\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n23 July 2019\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nMillet\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07VKYC3DK\n\n\nItem model number\n\u200f\n:\n\u200e\n\nMIG1330\n\n\nDepartment\n\u200f\n:\n\u200e\n\nMen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Sports & Outdoor Shoes/Trekking & Hiking Footwear/Trekking & Hiking Boots",
#   'images_list': ['https://m.media-amazon.com/images/I/416WiewUFJL.jpg',
#    'https://m.media-amazon.com/images/I/41MY+GGjalL.jpg',
#    'https://m.media-amazon.com/images/I/31YudpqSf2L.jpg',
#    'https://m.media-amazon.com/images/I/31ixnfV7RDL.jpg',
#    'https://m.media-amazon.com/images/I/31NK6jfGgLL.jpg',
#    'https://m.media-amazon.com/images/I/41nVlfSNfvL.jpg',
#    'https://m.media-amazon.com/images/I/41ixMjy3eEL.jpg'],
#   'features': [{'Outer Material': 'Leather'},
#    {'Inner Material': 'Manmade'},
#    {'Sole': 'Bast'},
#    {'Closure': 'Lace-Up'},
#    {'Shoe Width': 'Medium'},
#    {'Contents': 'Castle Gray (Light Gray)'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07T26WQF5',
#   'title': "adidas Originals Men's Superstar Foundation Sneaker",
#   'asin': 'B07T26WQF5',
#   'price': '£27.50 - £214.11',
#   'brand': 'adidas Originals',
#   'product_details': "Product Dimensions\n\u200f\n:\n\u200e\n\n30 x 35 x 20 cm; 200 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n18 Nov. 2019\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nadidas\n\n\nASIN\n\u200f\n:\n\u200e\n\nB0813VB74R\n\n\nItem model number\n\u200f\n:\n\u200e\n\nEG4960\n\n\nDepartment\n\u200f\n:\n\u200e\n\nMen's",
#   'breadcrumbs': "Shoes/Men's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/31PV8FxA9hL.jpg',
#    'https://m.media-amazon.com/images/I/31rM6XZH+mL.jpg',
#    'https://m.media-amazon.com/images/I/31TK9uSOD8L.jpg',
#    'https://m.media-amazon.com/images/I/31O-VlY70-L.jpg',
#    'https://m.media-amazon.com/images/I/31JvxRZkABL.jpg',
#    'https://m.media-amazon.com/images/I/31srUKGhBlL.jpg',
#    'https://m.media-amazon.com/images/I/31ZDmA7TNoL.jpg'],
#   'features': [{'Outer Material': 'Synthetic'},
#    {'Inner Material': 'Manmade'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Height': '1 centimetres'},
#    {'Heel Type': 'Flat'},
#    {'Material Composition': 'Leather'},
#    {'Shoe Width': 'Normale'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B0824F5JRM',
#   'title': "victoria Women's Tenis Piel/Virutas Glitter Sneaker",
#   'asin': 'B0824F5JRM',
#   'price': '£42.49 - £75.49',
#   'brand': 'VICTORIA',
#   'product_details': 'Package Dimensions\n\u200f\n:\n\u200e\n\n29 x 29 x 11 cm; 690 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n1 Dec. 2019\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nVictoria\n\n\nASIN\n\u200f\n:\n\u200e\n\nB0824F5JRM\n\n\nItem model number\n\u200f\n:\n\u200e\n\n1125188\n\n\nDepartment\n\u200f\n:\n\u200e\n\nUnisex',
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/41EgRWMfFGL.jpg',
#    'https://m.media-amazon.com/images/I/41V4o765pqL.jpg',
#    'https://m.media-amazon.com/images/I/51R1wrMDoRL.jpg',
#    'https://m.media-amazon.com/images/I/41XQjybB3GL.jpg',
#    'https://m.media-amazon.com/images/I/31Iapx2LA1L.jpg',
#    'https://m.media-amazon.com/images/I/31sRczUvUYL.jpg',
#    'https://m.media-amazon.com/images/I/41Z+ixc5vuL.jpg'],
#   'features': [{'Outer Material': 'Smooth Leather'},
#    {'Inner Material': 'Canvas'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Type': 'Low'},
#    {'Shoe Width': 'Medium'},
#    {'Shoe width': 'medium.'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08XJG46Q4',
#   'title': "ZYLDK Garden Shoes Children's Unisex Clogs Children's Bathing Shoes Hollow Mules Non-Slip Slippers with Cartoon Frog Bee Pink Size:",
#   'asin': 'B08XJG46Q4',
#   'price': '£8.06 - £9.10',
#   'brand': 'ZYLDK',
#   'product_details': 'Package Dimensions\n\u200f\n:\n\u200e\n\n23 x 19.1 x 7.8 cm; 100 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n26 Feb. 2021\n\n\nASIN\n\u200f\n:\n\u200e\n\nB08XGDS78M\n\n\nDepartment\n\u200f\n:\n\u200e\n\nUnisex Kids',
#   'breadcrumbs': '',
#   'images_list': ['https://m.media-amazon.com/images/I/4182E9SwDNL.jpg',
#    'https://m.media-amazon.com/images/I/410NfxsnsZL.jpg',
#    'https://m.media-amazon.com/images/I/41bETJE1RkL.jpg',
#    'https://m.media-amazon.com/images/I/41Xi765CdwL.jpg',
#    'https://m.media-amazon.com/images/I/41ar6Ndms7L.jpg',
#    'https://m.media-amazon.com/images/I/51oWjNFA4RL.jpg',
#    'https://m.media-amazon.com/images/I/417CPF0LP1L.jpg'],
#   'features': [{'Outer Material': 'EVA + synthetic. Breathable and comfortable, thin like a skin.'},
#    {'Inner Material': 'Unlined'},
#    {'Sole': 'Lightweight EVA sole, very light. Soft soles, comfortable and elastic.'},
#    {'Closure': 'Buckle'},
#    {'Heel Height': '2 centimetres'},
#    {'Heel Type': 'Flat'},
#    {'Shoe Width': 'Schmal'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08CF25Q1L',
#   'title': "Hugo Boss Men's Mirage_Tenn_oxcm Sneaker",
#   'asin': 'B08CF25Q1L',
#   'price': '£99.23 - £189.89',
#   'brand': 'Hugo Boss',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n36.2 x 19.9 x 12.7 cm; 1.37 Kilograms\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n7 July 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nHUGO BOSS\n\n\nASIN\n\u200f\n:\n\u200e\n\nB08CDZHCXS\n\n\nItem model number\n\u200f\n:\n\u200e\n\n50452155\n\n\nDepartment\n\u200f\n:\n\u200e\n\nMen's",
#   'breadcrumbs': "Shoes/Men's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/3149rshrw9S.jpg',
#    'https://m.media-amazon.com/images/I/41uaS4y1zeS.jpg',
#    'https://m.media-amazon.com/images/I/41EXKeQ008S.jpg',
#    'https://m.media-amazon.com/images/I/31XXN3ts+1S.jpg',
#    'https://m.media-amazon.com/images/I/31EuCZsi5cS.jpg',
#    'https://m.media-amazon.com/images/I/31dHdXQ6byS.jpg',
#    'https://m.media-amazon.com/images/I/313lbdYXWOS.jpg'],
#   'features': [{'Outer Material': 'Leather'},
#    {'Inner Material': 'Leather'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B09B455S7B',
#   'title': 'Absolute Footwear Mens Twin Gusset Slip On Velour Style Checked Winter Slippers',
#   'asin': 'B09B455S7B',
#   'price': '£16.99',
#   'brand': 'Visit the Absolute Footwear Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n31.8 x 15.6 x 10.4 cm; 680 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n23 July 2021\n\n\nASIN\n\u200f\n:\n\u200e\n\nB09B446F64\n\n\nDepartment\n\u200f\n:\n\u200e\n\nMen's",
#   'breadcrumbs': "Shoes/Men's Shoes/Slippers",
#   'images_list': ['https://m.media-amazon.com/images/I/41qDDJ5CiyL.jpg',
#    'https://m.media-amazon.com/images/I/41i-y1kqwxL.jpg',
#    'https://m.media-amazon.com/images/I/51LMFmK6qwL.jpg',
#    'https://m.media-amazon.com/images/I/31CtMHLrvdL.jpg',
#    'https://m.media-amazon.com/images/I/31drIW8SdWL.jpg',
#    'https://m.media-amazon.com/images/I/31TU8aXKgvL.jpg',
#    'https://m.media-amazon.com/images/I/41SR7apauBL.jpg'],
#   'features': [{'Sizs': 'UK 7 - 12'},
#    {'Outer Material': 'Textile'},
#    {'Inner Material': 'Textile'},
#    {'Sole': 'Synthetic'},
#    {'Closure': 'Pull On'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B0919PVV9Z',
#   'title': "adidas Men's Ultraboost 5.0 DNA Running Shoe, core Black/core Black/FTWR White, 10 UK",
#   'asin': 'B0919PVV9Z',
#   'price': '£140.00',
#   'brand': 'Visit the adidas Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n33 x 22.6 x 12.8 cm; 900 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n12 July 2021\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nAdidas\n\n\nASIN\n\u200f\n:\n\u200e\n\nB0919PVV9Z\n\n\nItem model number\n\u200f\n:\n\u200e\n\nFY9348\n\n\nCountry of origin\n\u200f\n:\n\u200e\n\nChina\n\n\nDepartment\n\u200f\n:\n\u200e\n\nMen's",
#   'breadcrumbs': "Shoes/Men's Shoes/Fashion & Athletic Trainers/Sports & Outdoor Shoes/Running Shoes/Road Running Shoes",
#   'images_list': ['https://m.media-amazon.com/images/I/41+wLQIk9uL.jpg',
#    'https://m.media-amazon.com/images/I/41jKBzvlN8L.jpg',
#    'https://m.media-amazon.com/images/I/41ucXx87HPL.jpg',
#    'https://m.media-amazon.com/images/I/41SyRI6G6UL.jpg',
#    'https://m.media-amazon.com/images/I/413qDSaUCzL.jpg',
#    'https://m.media-amazon.com/images/I/41JCaLnmPKL.jpg',
#    'https://m.media-amazon.com/images/I/41EL+iYn8PL.jpg'],
#   'features': [{'Outer Material': 'Cotton'},
#    {'Inner Material': 'Canvas'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Type': 'No Heel'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B084DQPC13',
#   'title': "Clarks Men's Bayhill Plain Oxford",
#   'asin': 'B084DQPC13',
#   'price': '£28.02 - £90.84',
#   'brand': 'Visit the Clarks Store',
#   'product_details': "Product Dimensions\n\u200f\n:\n\u200e\n\n30 x 20 x 10 cm; 860 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n28 Sept. 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nClarks\n\n\nASIN\n\u200f\n:\n\u200e\n\nB08JQFGBKS\n\n\nItem model number\n\u200f\n:\n\u200e\n\n261531758\n\n\nDepartment\n\u200f\n:\n\u200e\n\nMen's",
#   'breadcrumbs': "Shoes/Men's Shoes/Lace-ups",
#   'images_list': ['https://m.media-amazon.com/images/I/31B4LeV-WbL.jpg',
#    'https://m.media-amazon.com/images/I/412jkzCjB6L.jpg',
#    'https://m.media-amazon.com/images/I/41-HU6rtq5L.jpg',
#    'https://m.media-amazon.com/images/I/31wSdYxy+eL.jpg',
#    'https://m.media-amazon.com/images/I/31qVaT2nYYL.jpg',
#    'https://m.media-amazon.com/images/I/31fW4B5Hu7L.jpg',
#    'https://m.media-amazon.com/images/I/31Wr27F2MAL.jpg'],
#   'features': [{'Outer Material': 'Nubuck Leather'},
#    {'Inner Material': 'Manmade'},
#    {'Sole': 'Leather and rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Height': '1 centimetres'},
#    {'Heel Type': 'Flat'},
#    {'Shoe Width': 'Wide'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08898G4DM',
#   'title': "Kappa Unisex's Sneem Sneaker",
#   'asin': 'B08898G4DM',
#   'price': '£26.24 - £53.59',
#   'brand': 'Visit the Kappa Store',
#   'product_details': 'Package Dimensions\n\u200f\n:\n\u200e\n\n31.4 x 20 x 11.2 cm; 500 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n24 April 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nKappa\n\n\nASIN\n\u200f\n:\n\u200e\n\nB087DJ5V8W\n\n\nItem model number\n\u200f\n:\n\u200e\n\n242798\n\n\nDepartment\n\u200f\n:\n\u200e\n\nUnisex Kids',
#   'breadcrumbs': "Shoes/Men's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/41eDCN36+GL.jpg',
#    'https://m.media-amazon.com/images/I/41HQDFqs2YL.jpg',
#    'https://m.media-amazon.com/images/I/41rxJIBfEHL.jpg',
#    'https://m.media-amazon.com/images/I/31kqXfKlpnL.jpg',
#    'https://m.media-amazon.com/images/I/311r1-Gy42L.jpg',
#    'https://m.media-amazon.com/images/I/413YHAqTE5L.jpg',
#    'https://m.media-amazon.com/images/I/41ONGE8vtBL.jpg'],
#   'features': [{'Outer Material': 'Synthetic'},
#    {'Inner Material': 'Manmade'},
#    {'Sole': 'Ethylene Vinyl Acetate'},
#    {'Closure': 'Pull On'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08RXW73XF',
#   'title': "Teva Unisex Kid's K Midform Universal Sandals",
#   'asin': 'B08RXW73XF',
#   'price': '£27.00 - £85.69',
#   'brand': 'Visit the Teva Store',
#   'product_details': 'Package Dimensions\n\u200f\n:\n\u200e\n\n24.21 x 15.19 x 10.11 cm; 381 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n29 Jan. 2021\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nTEVA\n\n\nASIN\n\u200f\n:\n\u200e\n\nB08RXX93VV\n\n\nItem model number\n\u200f\n:\n\u200e\n\n1116671C\n\n\nDepartment\n\u200f\n:\n\u200e\n\nUnisex Kids',
#   'breadcrumbs': "Shoes/Boys' Shoes/Fashion & Athletic Trainers/Sports & Outdoor Shoes/Water Shoes",
#   'images_list': ['https://m.media-amazon.com/images/I/41U7yOvW4IS.jpg'],
#   'features': [{'Great for': 'all day wear, festivals, moving around town'},
#    {'Outer Material': 'Synthetic'},
#    {'Inner Material': 'Manmade'},
#    {'Sole': 'Synthetic'},
#    {'Closure': 'Hook and loop'},
#    {'Heel Type': 'Flat'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B00307JJR0',
#   'title': 'Capezio Websneaker, Girls’ Casual',
#   'asin': 'B00307JJR0',
#   'price': '£36.40 - £49.00',
#   'brand': 'Capezio',
#   'product_details': "Is Discontinued By Manufacturer\n\u200f\n:\n\u200e\n\nNo\n\n\nPackage Dimensions\n\u200f\n:\n\u200e\n\n23.8 x 14.6 x 9.2 cm; 458.13 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n28 Sept. 2010\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nCapezio\n\n\nASIN\n\u200f\n:\n\u200e\n\nB002ZMTUL6\n\n\nItem model number\n\u200f\n:\n\u200e\n\nS000DS19C0MPAT125\n\n\nDepartment\n\u200f\n:\n\u200e\n\nGirl's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Sports & Outdoor Shoes",
#   'images_list': ['https://m.media-amazon.com/images/I/41Vt3Tj1QKL.jpg',
#    'https://m.media-amazon.com/images/I/41riQrO0ohL.jpg',
#    'https://m.media-amazon.com/images/I/41lrVmFhYJL.jpg',
#    'https://m.media-amazon.com/images/I/31Ll2xhEXkL.jpg',
#    'https://m.media-amazon.com/images/I/31ZPOr8r-iL.jpg',
#    'https://m.media-amazon.com/images/I/31D2vzKr-bL.jpg',
#    'https://m.media-amazon.com/images/I/51UJMw+OZmL.jpg'],
#   'features': [{'Outer Material': 'Mesh'},
#    {'Inner Material': 'Manmade'},
#    {'Sole': 'Polyurethane'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Height': '1 centimetres'},
#    {'Heel Type': 'Flat'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07TVF6ZBP',
#   'title': "Skechers Women's Ultra Groove Trainers",
#   'asin': 'B07TVF6ZBP',
#   'price': '£40.31 - £199.90',
#   'brand': 'Visit the Skechers Store',
#   'product_details': "Batteries\n\u200f\n:\n\u200e\n\n1 Unknown batteries required.\n\n\nIs Discontinued By Manufacturer\n\u200f\n:\n\u200e\n\nNo\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n9 Sept. 2019\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nSkechers\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07TTDKR5L\n\n\nItem model number\n\u200f\n:\n\u200e\n\n149019\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/4105lS5DErL.jpg',
#    'https://m.media-amazon.com/images/I/41Ao60M9swL.jpg',
#    'https://m.media-amazon.com/images/I/41vFoI9bGjL.jpg',
#    'https://m.media-amazon.com/images/I/31D7xyC46rL.jpg',
#    'https://m.media-amazon.com/images/I/31eewoLkYWL.jpg',
#    'https://m.media-amazon.com/images/I/41+7Sbi3ylL.jpg',
#    'https://m.media-amazon.com/images/I/41nXEm1EipL.jpg'],
#   'features': [{'Upper': 'Textile'},
#    {'Lining': 'Textile'},
#    {'Outer Material': 'Synthetic'},
#    {'Inner Material': 'Textile'},
#    {'Sole': 'Ethylene Vinyl Acetate'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Type': 'No Heel'},
#    {'Shoe Width': 'Medium'},
#    {'Sole': 'EVA'},
#    {'Heel Height': '45'},
#    {'Width': 'Standard'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07W6S18DB',
#   'title': 'Rieker Women Low Shoes, Loafers L2327, Ladies Low-Tops,Removable Insole',
#   'asin': 'B07W6S18DB',
#   'price': '£29.39 - £41.35',
#   'brand': 'Rieker',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n32.2 x 17.2 x 11.6 cm; 600 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n8 Aug. 2019\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nRieker\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07W6S16VZ\n\n\nItem model number\n\u200f\n:\n\u200e\n\nL2327\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Flat Shoes/Loafers & Moccasins",
#   'images_list': ['https://m.media-amazon.com/images/I/41IyKyn39IL.jpg',
#    'https://m.media-amazon.com/images/I/41H0mKED6DL.jpg',
#    'https://m.media-amazon.com/images/I/31EfSTJwvnL.jpg',
#    'https://m.media-amazon.com/images/I/31do7yetmuL.jpg',
#    'https://m.media-amazon.com/images/I/41aoDZ-yWLL.jpg',
#    'https://m.media-amazon.com/images/I/41oKiyT8YKL.jpg',
#    'https://m.media-amazon.com/images/I/4164t8o2+6L.jpg'],
#   'features': [{'Product type': 'Low shoes, Loafers,Low-tops,low shoe,street shoe,lace up,lace up shoe,sports shoe,platform sole,leisure'},
#    {'Outer material': 'textile'},
#    {'Outer Material': 'Synthetic'},
#    {'Inner Material': 'Manmade'},
#    {'Sole': 'Synthetic'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Height': '3.5 centimetres'},
#    {'Heel Type': 'Flat'},
#    {'Shoe Width': 'Medium'},
#    {'Heel type': 'ankle'},
#    {'Width': 'Lace-Up'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08Z7SY2R9',
#   'title': 'Little/Big Boys Girls Lightweight Graffiti Personality Shoes Kids Sneaker Mesh Breathable Athletic Running Tennis Shoes(Size:30,Color:C)',
#   'asin': 'B08Z7SY2R9',
#   'price': '£22.93',
#   'brand': 'QBSW',
#   'product_details': '',
#   'breadcrumbs': "Shoes/Boys' Shoes/Sandals",
#   'images_list': ['https://m.media-amazon.com/images/I/41te42GqtKL.jpg',
#    'https://m.media-amazon.com/images/I/41gyUdNLHKL.jpg',
#    'https://m.media-amazon.com/images/I/41jNrWW8oWL.jpg',
#    'https://m.media-amazon.com/images/I/51XzjbHwHKL.jpg',
#    'https://m.media-amazon.com/images/I/41usxHbeYYL.jpg',
#    'https://m.media-amazon.com/images/I/41oBUAgN56L.jpg',
#    'https://m.media-amazon.com/images/I/51-DXTWevdL.jpg'],
#   'features': [{'Occasions': 'outdoor sports, vacation, school, church, travel, walking with dogs, daily wear, etc.'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07XJR94FR',
#   'title': "dockers Men's Sunland Slide Sandal",
#   'asin': 'B07XJR94FR',
#   'price': '£37.15 - £162.50',
#   'brand': 'Visit the Dockers Store',
#   'product_details': "Is Discontinued By Manufacturer\n\u200f\n:\n\u200e\n\nNo\n\n\nProduct Dimensions\n\u200f\n:\n\u200e\n\n25.4 x 38.1 x 15.24 cm; 340.19 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n17 Nov. 2016\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nDockers Footwear\n\n\nASIN\n\u200f\n:\n\u200e\n\nB01LZGTAJF\n\n\nItem model number\n\u200f\n:\n\u200e\n\n90-21398\n\n\nDepartment\n\u200f\n:\n\u200e\n\nMen's",
#   'breadcrumbs': "Shoes/Men's Shoes/Sandals",
#   'images_list': ['https://m.media-amazon.com/images/I/31gygukQhsL.jpg',
#    'https://m.media-amazon.com/images/I/51OWnyA2LYL.jpg',
#    'https://m.media-amazon.com/images/I/41-3bmbJNML.jpg',
#    'https://m.media-amazon.com/images/I/31j3yKl4jLL.jpg',
#    'https://m.media-amazon.com/images/I/31xOoMGychL.jpg',
#    'https://m.media-amazon.com/images/I/31HnRbldQBL.jpg',
#    'https://m.media-amazon.com/images/I/31qWb4k630L.jpg'],
#   'features': [{'Outer Material': 'Faux Leather'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Slip On'},
#    {'Heel Height': '1 inches'},
#    {'Heel Type': 'low-heel'},
#    {'Shoe Width': 'Medium mens_us'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B071HXDK1Z',
#   'title': "Nine West Kids' Odettah Sneaker, Grey Jersey, Size 6 Medium US Big Kid US/US",
#   'asin': 'B071HXDK1Z',
#   'price': '£31.43',
#   'brand': 'NINE WEST',
#   'product_details': "Product Dimensions\n\u200f\n:\n\u200e\n\n12.7 x 12.7 x 1.78 cm; 294.84 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n23 Oct. 2017\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nNine West Kids\n\n\nASIN\n\u200f\n:\n\u200e\n\nB071HXDK1Z\n\n\nItem model number\n\u200f\n:\n\u200e\n\n9W100280G\n\n\nDepartment\n\u200f\n:\n\u200e\n\nGirl's",
#   'breadcrumbs': "Shoes/Girls' Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/41QLa6nt5XL.jpg',
#    'https://m.media-amazon.com/images/I/517ie0SQJQL.jpg',
#    'https://m.media-amazon.com/images/I/511A98FLp3L.jpg',
#    'https://m.media-amazon.com/images/I/41wGq3Q3btL.jpg',
#    'https://m.media-amazon.com/images/I/411Enic5oOL.jpg',
#    'https://m.media-amazon.com/images/I/31TnjpC-McL.jpg',
#    'https://m.media-amazon.com/images/I/41GWAzVyCPL.jpg'],
#   'features': [{'Outer Material': 'Synthetic'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Pull On'},
#    {'Shoe Width': 'M'},
#    {'style': 'Odettah'},
#    {'closure_type': 'Slip-On'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B09C8C5T8K',
#   'title': 'Walk Shoes Women Athletic Casual Tennis Sneakers Lace Up Walking Shoes Striped Pattern Autumn Loafers',
#   'asin': 'B09C8C5T8K',
#   'price': '£17.68 - £18.28',
#   'brand': 'JYC Store',
#   'product_details': "Date First Available\n\u200f\n:\n\u200e\n\n10 Aug. 2021\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nzhjk598\n\n\nASIN\n\u200f\n:\n\u200e\n\nB09C8B5L7H\n\n\nItem model number\n\u200f\n:\n\u200e\n\nwomen sandals clearance\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/41+GJL894TS.jpg',
#    'https://m.media-amazon.com/images/I/61p6xGBYBUS.jpg',
#    'https://m.media-amazon.com/images/I/611-z94F6pS.jpg',
#    'https://m.media-amazon.com/images/I/61R4I7CeCZS.jpg',
#    'https://m.media-amazon.com/images/I/51CPIGt9ewS.jpg',
#    'https://m.media-amazon.com/images/I/5186i6L8P9S.jpg',
#    'https://m.media-amazon.com/images/I/41i3VF92QXL.jpg'],
#   'features': [{'Outer Material': "Canvas, boys trainers, badminton shoes, women's walking shoes, running shoes for wome"},
#    {'Inner Material': "Wedge, pointed-toe, women's slippers, white trainers women"},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up, Pull On, Hook & Loop'},
#    {'Heel Height': '1.5 centimetres'},
#    {'Heel Type': 'Low'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07P23G5X9',
#   'title': "Skechers Men's Dyna-air - Blyce Trainers",
#   'asin': 'B07P23G5X9',
#   'price': '£46.00 - £144.26',
#   'brand': 'Visit the Skechers Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n33.02 x 22.35 x 12.69 cm; 770 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n20 Feb. 2019\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nSkechers\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07P23CT99\n\n\nItem model number\n\u200f\n:\n\u200e\n\n52558\n\n\nDepartment\n\u200f\n:\n\u200e\n\nMen's",
#   'breadcrumbs': "Shoes/Men's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/410vpTfvXNL.jpg',
#    'https://m.media-amazon.com/images/I/51k5ljDwwjL.jpg',
#    'https://m.media-amazon.com/images/I/41vwxRibYAL.jpg',
#    'https://m.media-amazon.com/images/I/41UmwaMM9kL.jpg',
#    'https://m.media-amazon.com/images/I/41U2h9zA22L.jpg',
#    'https://m.media-amazon.com/images/I/41BxWTUBPsL.jpg',
#    'https://m.media-amazon.com/images/I/41VH-yA01rL.jpg'],
#   'features': [{'Outer Material': 'Synthetic'},
#    {'Inner Material': 'Textile'},
#    {'Sole': 'Ethylene Vinyl Acetate'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Type': 'Flat'},
#    {'Shoe Width': 'Medium mens_us'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07DW6XC32',
#   'title': 'Puma - Infant Suede Classic Bboy Fabulous Shoes',
#   'asin': 'B07DW6XC32',
#   'price': '£75.95 - £104.14',
#   'brand': 'Visit the PUMA Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n18.03 x 14.73 x 7.62 cm; 1.36 Kilograms\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n2 Mar. 2018\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nPuma\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07DW84SJH\n\n\nItem model number\n\u200f\n:\n\u200e\n\n365130-02\n\n\nDepartment\n\u200f\n:\n\u200e\n\nBoy's",
#   'breadcrumbs': 'Shoes/Baby Shoes/Baby Boys/First Walking Shoes',
#   'images_list': ['https://m.media-amazon.com/images/I/41ZdwZEHJCL.jpg',
#    'https://m.media-amazon.com/images/I/41nCRg7k83L.jpg',
#    'https://m.media-amazon.com/images/I/41rnV1x1baL.jpg',
#    'https://m.media-amazon.com/images/I/41u3LHhDxwL.jpg'],
#   'features': [{'Outer Material': 'Synthetic'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08J7ZXK8C',
#   'title': "IGI&Co Men's Urt 71131 Oxford",
#   'asin': 'B08J7ZXK8C',
#   'price': '£17.96 - £78.72',
#   'brand': 'IGI&Co',
# ...
#   'breadcrumbs': "Shoes/Men's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/41nXPoJDHdL.jpg',
#    'https://m.media-amazon.com/images/I/41cyqjmSHCL.jpg',
#    'https://m.media-amazon.com/images/I/41auRD462dL.jpg',
#    'https://m.media-amazon.com/images/I/317TkCuSoTL.jpg',
#    'https://m.media-amazon.com/images/I/31yjS7lkP+L.jpg',
#    'https://m.media-amazon.com/images/I/31m3ZAf-SYL.jpg',
#    'https://m.media-amazon.com/images/I/41TVO-SWHLL.jpg'],
#   'features': [{'Sole': 'Suede, Rubber, Ethylene Vinyl Acetate'},
#    {'Closure': 'Lace-Up'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07TYWKC3C',
#   'title': "Cole Haan Women's Grand Sport Stitchlite Knit Trainer",
#   'asin': 'B07TYWKC3C',
#   'price': '£60.86 - £105.52',
#   'brand': 'Visit the Cole Haan Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n31.5 x 18.8 x 11.43 cm; 640 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n4 July 2019\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nCole Haan\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07TXRR1B8\n\n\nItem model number\n\u200f\n:\n\u200e\n\nW17108\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/41HW+JJGICL.jpg',
#    'https://m.media-amazon.com/images/I/4166onabsyL.jpg',
#    'https://m.media-amazon.com/images/I/31OmWZkqkHL.jpg'],
#   'features': [{'Outer Material': 'Leather'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08BG4ZXFW',
#   'title': "Reef Women's Cushion Sunset Sneaker, Black/Tan, 7 UK",
#   'asin': 'B08BG4ZXFW',
#   'price': None,
#   'brand': 'Visit the Reef Store',
#   'product_details': "Product Dimensions\n\u200f\n:\n\u200e\n\n22.86 x 15.24 x 5.08 cm; 880 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n25 Jun. 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nReef\n\n\nASIN\n\u200f\n:\n\u200e\n\nB08BG4ZXFW\n\n\nItem model number\n\u200f\n:\n\u200e\n\nCI4139\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/31E1f49DaCS.jpg',
#    'https://m.media-amazon.com/images/I/31XkyoiDDHS.jpg',
#    'https://m.media-amazon.com/images/I/41sKvRa2GKS.jpg',
#    'https://m.media-amazon.com/images/I/41W9R6ZwtUS.jpg',
#    'https://m.media-amazon.com/images/I/31sMwXFaFjS.jpg',
#    'https://m.media-amazon.com/images/I/31m9aPs6odS.jpg',
#    'https://m.media-amazon.com/images/I/31pX4A9-bCS.jpg'],
#   'features': [{'Outer Material': 'Canvas'},
#    {'Inner Material': 'Manmade'},
#    {'Sole': 'Ethylene Vinyl Acetate'},
#    {'Closure': 'Hatch'},
#    {'Heel Type': 'Low'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07QLVLV1Y',
#   'title': "KIMBERFEEL Women's Denali High Leather Hiking Shoe with a vibrational Sole",
#   'asin': 'B07QLVLV1Y',
#   'price': '£69.25',
#   'brand': 'KIMBERFEEL',
#   'product_details': "Date First Available\n\u200f\n:\n\u200e\n\n8 Jun. 2021\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nKIMBERFEEL\n\n\nASIN\n\u200f\n:\n\u200e\n\nB096VZ14TG\n\n\nItem model number\n\u200f\n:\n\u200e\n\nDENALI\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/51xV9z8gDML.jpg',
#    'https://m.media-amazon.com/images/I/41K1m71ueaL.jpg',
#    'https://m.media-amazon.com/images/I/414pf-zMfIL.jpg',
#    'https://m.media-amazon.com/images/I/41jn1HGPt3L.jpg'],
#   'features': [{'Inner Material': 'Manmade'},
#    {'Sole': 'Other'},
#    {'Closure': 'Lace-Up'},
#    {'Shoe Width': 'N'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08BT53X5W',
#   'title': "Teva Girl's Y Tirra",
#   'asin': 'B08BT53X5W',
#   'price': '£20.70 - £52.66',
#   'brand': 'Visit the Teva Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n27.43 x 17.78 x 11.18 cm; 599 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n7 July 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nTeva\n\n\nASIN\n\u200f\n:\n\u200e\n\nB08BSZTR8Z\n\n\nItem model number\n\u200f\n:\n\u200e\n\n1019395Y\n\n\nDepartment\n\u200f\n:\n\u200e\n\nGirl's",
#   'breadcrumbs': '',
#   'images_list': ['https://m.media-amazon.com/images/I/41tHq1rSBnL.jpg',
#    'https://m.media-amazon.com/images/I/51PwI+UaKZL.jpg',
#    'https://m.media-amazon.com/images/I/418PNGNlFSL.jpg',
#    'https://m.media-amazon.com/images/I/31KPoqDseyL.jpg',
#    'https://m.media-amazon.com/images/I/41d6614UnHL.jpg',
#    'https://m.media-amazon.com/images/I/41n2CyuIpyL.jpg',
#    'https://m.media-amazon.com/images/I/41Db7AFXOYL.jpg'],
#   'features': [{'Outer Material': 'Synthetic'},
#    {'Inner Material': 'Manmade'},
#    {'Sole': 'Synthetic Rubber'},
#    {'Closure': 'Hook & Loop'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07NXBLQYW',
#   'title': "Propét Women's TravelActiv Se Sneaker",
#   'asin': 'B07NXBLQYW',
#   'price': '£46.14',
#   'brand': 'Propet',
#   'product_details': "Date First Available\n\u200f\n:\n\u200e\n\n29 Sept. 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nPropet\n\n\nASIN\n\u200f\n:\n\u200e\n\nB08KFRR58X\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/5157U-GI4PL.jpg',
#    'https://m.media-amazon.com/images/I/51VgWNJppeL.jpg',
#    'https://m.media-amazon.com/images/I/51mVcKEX91L.jpg',
#    'https://m.media-amazon.com/images/I/31RzHJ6FY0L.jpg',
#    'https://m.media-amazon.com/images/I/41ICKuAAKZL.jpg',
#    'https://m.media-amazon.com/images/I/413AvG9FZtL.jpg',
#    'https://m.media-amazon.com/images/I/51-WqU8iAqL.jpg'],
#   'features': [{'Outer Material': 'fabric'},
#    {'Sole': 'Synthetic'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Height': '1.5 inches'},
#    {'Heel Type': 'low-heel'},
#    {'Shoe Width': 'W (D)'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B083MSBCPP',
#   'title': "Converse All Star Hi, Unisex Adults' High Trainers",
#   'asin': 'B083MSBCPP',
#   'price': '£107.55 - £156.43',
#   'brand': 'Converse',
#   'product_details': 'Is Discontinued By Manufacturer\n\u200f\n:\n\u200e\n\nNo\n\n\nPackage Dimensions\n\u200f\n:\n\u200e\n\n30.99 x 12.7 x 10.16 cm; 997.9 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n10 Mar. 2016\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nConverse\n\n\nASIN\n\u200f\n:\n\u200e\n\nB01CTF91JE\n\n\nManufacturer reference\n\u200f\n:\n\u200e\n\nCONCT-ASBLBL:BO02',
#   'breadcrumbs': "Shoes/Men's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/31u4lZ2PDaL.jpg',
#    'https://m.media-amazon.com/images/I/31J23uCjkIL.jpg',
#    'https://m.media-amazon.com/images/I/41+XMk4AviL.jpg',
#    'https://m.media-amazon.com/images/I/218ITIXi5EL.jpg',
#    'https://m.media-amazon.com/images/I/21N4NKzMZSL.jpg',
#    'https://m.media-amazon.com/images/I/317S3ES2PmL.jpg',
#    'https://m.media-amazon.com/images/I/21yYk6AYb9L.jpg'],
#   'features': [{'Outer Material': 'Canvas'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08MTDXHVR',
#   'title': 'Skechers Kids Unisex-Child 302914l Combat Boot',
#   'asin': 'B08MTDXHVR',
#   'price': '£59.00',
#   'brand': 'Skechers Kids',
#   'product_details': 'Date First Available\n\u200f\n:\n\u200e\n\n4 Nov. 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nSkechers Kids\n\n\nASIN\n\u200f\n:\n\u200e\n\nB09DH6TGC2\n\n\nItem model number\n\u200f\n:\n\u200e\n\n302914L\n\n\nDepartment\n\u200f\n:\n\u200e\n\nUnisex Kids',
#   'breadcrumbs': "Shoes/Girls' Shoes/Boots",
#   'images_list': ['https://m.media-amazon.com/images/I/41Ay+TD6A3L.jpg',
#    'https://m.media-amazon.com/images/I/31e34OlvsLL.jpg',
#    'https://m.media-amazon.com/images/I/31e3TZ7GIaL.jpg',
#    'https://m.media-amazon.com/images/I/314ZwLhw0WL.jpg',
#    'https://m.media-amazon.com/images/I/31v90s6yXuL.jpg',
#    'https://m.media-amazon.com/images/I/31qSkWmirNL.jpg',
#    'https://m.media-amazon.com/images/I/411OTt8eKtL.jpg'],
#   'features': [{'Outer Material': 'Rubber'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Zip'},
#    {'Heel Type': 'Platform'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07XVSQJDD',
#   'title': "Skechers Women's Skech-air Element 2.0-Dance T Trainers",
#   'asin': 'B07XVSQJDD',
#   'price': '£48.53 - £166.75',
#   'brand': 'Visit the Skechers Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n25.9 x 18.03 x 9.9 cm; 703 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n13 Sept. 2019\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nSkechers\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07TWHZM27\n\n\nItem model number\n\u200f\n:\n\u200e\n\n149042\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/41JO-6S4HrL.jpg',
#    'https://m.media-amazon.com/images/I/51+v-0onTGL.jpg',
#    'https://m.media-amazon.com/images/I/4158UnU1uEL.jpg',
#    'https://m.media-amazon.com/images/I/31Gd-3ECMOL.jpg',
#    'https://m.media-amazon.com/images/I/41QoYSHSyzL.jpg',
#    'https://m.media-amazon.com/images/I/416xUAhe2HL.jpg',
#    'https://m.media-amazon.com/images/I/41Awf0C+JbL.jpg'],
#   'features': [{'Upper': 'Textile'},
#    {'Lining': 'Textile'},
#    {'Outer Material': 'Synthetic'},
#    {'Inner Material': 'Textile'},
#    {'Sole': 'Ethylene Vinyl Acetate'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Type': 'Low'},
#    {'Shoe Width': 'Medium'},
#    {'Sole': 'EVA'},
#    {'Heel Height': '35'},
#    {'Width': 'Standard'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B091B1XCCL',
#   'title': 'Absolute Footwear Womens Lightweight Knitted Style Lace Up Tainers Pumps Shoes with Memory Foam Insole',
#   'asin': 'B091B1XCCL',
#   'price': '£24.49',
#   'brand': 'Visit the Absolute Footwear Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n29 x 18 x 10 cm; 500 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n29 Mar. 2021\n\n\nASIN\n\u200f\n:\n\u200e\n\nB091B1XCCL\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/51VmkbcEuOL.jpg',
#    'https://m.media-amazon.com/images/I/41EDWWzTyHL.jpg',
#    'https://m.media-amazon.com/images/I/51YADokuiCL.jpg',
#    'https://m.media-amazon.com/images/I/413g78Q-YZL.jpg',
#    'https://m.media-amazon.com/images/I/410AZe8H3aL.jpg',
#    'https://m.media-amazon.com/images/I/41lkKn1kpcL.jpg',
#    'https://m.media-amazon.com/images/I/31GbDfSgcUL.jpg'],
#   'features': [{'Sizes': 'UK 4 - 8'},
#    {'Outer Material': 'Textile'},
#    {'Inner Material': 'Textile'},
#    {'Sole': 'Synthetic'},
#    {'Closure': 'Lace-Up'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B07T5FNKTC',
#   'title': "adidas Women's Astrarun W Running Shoe",
#   'asin': 'B07T5FNKTC',
#   'price': '£37.39 - £189.17',
#   'brand': 'Visit the adidas Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n29.08 x 19.43 x 10.54 cm; 1.36 Kilograms\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n19 Aug. 2019\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nadidas\n\n\nASIN\n\u200f\n:\n\u200e\n\nB07WVL55H7\n\n\nItem model number\n\u200f\n:\n\u200e\n\nGNG31\n\n\nDepartment\n\u200f\n:\n\u200e\n\nMen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Sports & Outdoor Shoes/Cross Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/41ZKLW5ZMNL.jpg',
#    'https://m.media-amazon.com/images/I/419RsID2pXL.jpg',
#    'https://m.media-amazon.com/images/I/41eZ51ZYEAL.jpg',
#    'https://m.media-amazon.com/images/I/31WwD4gSCsL.jpg',
#    'https://m.media-amazon.com/images/I/316AYyDHIBL.jpg',
#    'https://m.media-amazon.com/images/I/4152Nj5QeoL.jpg'],
#   'features': [{'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Type': 'Low'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08DVCM5T9',
#   'title': "s.Oliver Women's 5-5-23678-26 Sneaker",
#   'asin': 'B08DVCM5T9',
#   'price': '£12.24 - £40.51',
#   'brand': 'Visit the s.Oliver Store',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n31 x 20.6 x 11.4 cm; 860 Grams\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n29 July 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nshoe.com GmbH & Co. KG\n\n\nASIN\n\u200f\n:\n\u200e\n\nB08DVCN6V5\n\n\nItem model number\n\u200f\n:\n\u200e\n\n5-5-23678-26\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/41W4S-rjCuS.jpg',
#    'https://m.media-amazon.com/images/I/41Infsqa1MS.jpg',
#    'https://m.media-amazon.com/images/I/41eDbyYBoHS.jpg',
#    'https://m.media-amazon.com/images/I/31lMugMoyoS.jpg',
#    'https://m.media-amazon.com/images/I/31Gt148riMS.jpg',
#    'https://m.media-amazon.com/images/I/31GVr+5cujS.jpg',
#    'https://m.media-amazon.com/images/I/41VTRkYFhOS.jpg'],
#   'features': [{'Outer Material': 'Canvas'},
#    {'Inner Material': 'Textile'},
#    {'Sole': 'Synthetic'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Type': 'Flat'},
#    {'Shoe Width': 'Medium'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08ZJ4XJST',
#   'title': "Girls' Boys' Shoes Cool LED Flash Summer Outdoor Beach Sandals Closed-Toe Breathable Fashionable Running Sports Shoes Kid Breathable Pink Black(Size:30,Color:Black)",
#   'asin': 'B08ZJ4XJST',
#   'price': '£19.65',
#   'brand': 'QBSW',
#   'product_details': '',
#   'breadcrumbs': "Shoes/Boys' Shoes/Fashion & Athletic Trainers/Sports & Outdoor Shoes/Sports & Outdoor Sandals",
#   'images_list': ['https://m.media-amazon.com/images/I/41C60dUYk9L.jpg',
#    'https://m.media-amazon.com/images/I/51wZniVBqiL.jpg',
#    'https://m.media-amazon.com/images/I/51bgkA4jLML.jpg',
#    'https://m.media-amazon.com/images/I/51h3bqdEmuL.jpg',
#    'https://m.media-amazon.com/images/I/41-E9M5OZVL.jpg',
#    'https://m.media-amazon.com/images/I/41eM0gPEQfL.jpg',
#    'https://m.media-amazon.com/images/I/41auwU6dfGL.jpg'],
#   'features': [{'💥Occasions': 'outdoor sports, vacation, school, church, travel, walking with dogs, daily wear, etc.which will not make your feet feel hot and sweaty even in hot summer, and make you feel fresh and comfortable all day long.'}]},
#  {'url': 'https://www.amazon.co.uk/dp/B08KDSM58G',
#   'title': "Laura Vita Women's Hocimalo 271 Sneaker",
#   'asin': 'B08KDSM58G',
#   'price': '£30.17 - £88.43',
#   'brand': 'Laura Vita',
#   'product_details': "Package Dimensions\n\u200f\n:\n\u200e\n\n30 x 25 x 12 cm; 1.1 Kilograms\n\n\nDate First Available\n\u200f\n:\n\u200e\n\n29 Sept. 2020\n\n\nManufacturer\n\u200f\n:\n\u200e\n\nLAURA VITA\n\n\nASIN\n\u200f\n:\n\u200e\n\nB08KDMHPN9\n\n\nItem model number\n\u200f\n:\n\u200e\n\nHOCIMALO 271\n\n\nDepartment\n\u200f\n:\n\u200e\n\nWomen's",
#   'breadcrumbs': "Shoes/Women's Shoes/Fashion & Athletic Trainers/Fashion Trainers",
#   'images_list': ['https://m.media-amazon.com/images/I/41wsZuoNrxS.jpg',
#    'https://m.media-amazon.com/images/I/51SDnepRVmS.jpg',
#    'https://m.media-amazon.com/images/I/417CEsJXUKS.jpg',
#    'https://m.media-amazon.com/images/I/31CCb9CSUTS.jpg',
#    'https://m.media-amazon.com/images/I/41-p6xUsr6S.jpg',
#    'https://m.media-amazon.com/images/I/417yi2zjvES.jpg',
#    'https://m.media-amazon.com/images/I/41oPJE+oLdS.jpg'],
#   'features': [{'Outer Material': 'smooth_leather'},
#    {'Inner Material': 'Leather, canvas.'},
#    {'Sole': 'Rubber'},
#    {'Closure': 'Lace-Up'},
#    {'Heel Height': '1 centimetres'},
#    {'Heel Type': 'Flat'},
#    {'Shoe Width': 'Medium'}]},
#  ...]

# %% [markdown]
# ### Procesing json file data to Data frames

# %%
import pandas as pd

def process_dataset(data):
    # Initialize lists to store processed data
    urls = []
    titles = []
    asins = []
    prices = []
    brands = []
    package_dimensions = []
    date_first_available = []
    manufacturers = []
    asin_numbers = []
    item_model_numbers = []
    countries_of_origin = []
    departments = []
    breadcrumbs = []
    images_lists = []
    outer_materials = []
    inner_materials = []
    soles = []
    closures = []
    heel_heights = []
    heel_types = []
    shoe_widths = []

    # Process each item in the dataset
    for item in data:
        # Append values to respective lists
        urls.append(item.get('url'))
        titles.append(item.get('title'))
        asins.append(item.get('asin'))
        prices.append(item.get('price'))
        brands.append(item.get('brand'))

        # Process product details
        product_details = item.get('product_details').split('\n\n\n')
        package_dimensions.append(product_details[0].split(':')[-1].strip() if len(product_details) > 0 else None)
        date_first_available.append(product_details[1].split(':')[-1].strip() if len(product_details) > 1 else None)
        manufacturers.append(product_details[2].split(':')[-1].strip() if len(product_details) > 2 else None)
        asin_numbers.append(product_details[3].split(':')[-1].strip() if len(product_details) > 3 else None)
        item_model_numbers.append(product_details[4].split(':')[-1].strip() if len(product_details) > 4 else None)
        countries_of_origin.append(product_details[5].split(':')[-1].strip() if len(product_details) > 5 else None)
        departments.append(product_details[6].split(':')[-1].strip() if len(product_details) > 6 else None)

        # Process breadcrumbs
        breadcrumbs.append(item.get('breadcrumbs'))

        # Process images list
        images_lists.append(item.get('images_list'))

        # Process features
        features = item.get('features')
        outer_materials.append(next((f['Outer Material'] for f in features if 'Outer Material' in f), None))
        inner_materials.append(next((f['Inner Material'] for f in features if 'Inner Material' in f), None))
        soles.append(next((f['Sole'] for f in features if 'Sole' in f), None))
        closures.append(next((f['Closure'] for f in features if 'Closure' in f), None))
        heel_heights.append(next((f['Heel Height'] for f in features if 'Heel Height' in f), None))
        heel_types.append(next((f['Heel Type'] for f in features if 'Heel Type' in f), None))
        shoe_widths.append(next((f['Shoe Width'] for f in features if 'Shoe Width' in f), None))

    # Create DataFrame from processed data
    df = pd.DataFrame({
        'url': urls,
        'title': titles,
        'asin': asins,
        'price': prices,
        'brand': brands,
        'package_dimensions': package_dimensions,
        'date_first_available': date_first_available,
        'manufacturer': manufacturers,
        'asin_number': asin_numbers,
        'item_model_number': item_model_numbers,
        'country_of_origin': countries_of_origin,
        'department': departments,
        'breadcrumbs': breadcrumbs,
        'images_list': images_lists,
        'outer_material': outer_materials,
        'inner_material': inner_materials,
        'sole': soles,
        'closure': closures,
        'heel_height': heel_heights,
        'heel_type': heel_types,
        'shoe_width': shoe_widths
    })

    return df

# %%
# Process the dataset
processed_df = process_dataset(data)

# %%
# Display the processed DataFrame
processed_df.head()
# Out:
#                                       url  \
# 0  https://www.amazon.co.uk/dp/B08BLP231K
# 1  https://www.amazon.co.uk/dp/B08N587YZ9
# 2  https://www.amazon.co.uk/dp/B0918K4H1W
# 3  https://www.amazon.co.uk/dp/B07KMB98CG
# 4  https://www.amazon.co.uk/dp/B08CN3S1ZK
#
#                                                title        asin  \
# 0  Geox Jr Sandal Strada B Fisherman, Brown Red, ...  B08BLP231K
# 1                    Fila Women's Oakmont Tr Sneaker  B08N587YZ9
# 2  Gabor Rollingsoft Trainers in Plus Sizes Beige...  B0918K4H1W
# 3  Merrell Women'S Bare Access Xtr Trail Running ...  B07KMB98CG
# 4  Desigual Women's Shoes_Runner_cmofl Sneakers W...  B08CN3S1ZK
#
#               price                    brand  \
# 0            £50.00     Visit the Geox Store
# 1  £49.57 - £234.95                     Fila
# 2              None                    Gabor
# 3  £67.00 - £182.44  Visit the Merrell Store
# 4   £38.96 - £81.10                 Desigual
#
#                             package_dimensions date_first_available  \
# 0        ‎\n\n31.2 x 21.4 x 11.4 cm; 820 Grams    ‎\n\n22 Jun. 2020
# 1  ‎\n\n32.51 x 21.84 x 12.19 cm; 952.54 Grams     ‎\n\n6 Jun. 2020
# 2                                      ‎\n\nNo   ‎\n\n26 April 2021
# 3     ‎\n\n28.96 x 19.81 x 10.16 cm; 544 Grams    ‎\n\n20 Jan. 2020
# 4        ‎\n\n34.6 x 21.8 x 11.6 cm; 500 Grams    ‎\n\n13 July 2020
#
#        manufacturer      asin_number  item_model_number  ...  department  \
# 0         ‎\n\nGeox  ‎\n\nB08BLP231K   ‎\n\nJ1524B02214  ...  ‎\n\nBoy's
# 1         ‎\n\nFila  ‎\n\nB089RQLYNW  ‎\n\n5JM00948-990  ...        None
# 2  ‎\n\nrollingsoft  ‎\n\nB0918K4H1W     ‎\n\n66.938-30  ...        None
# 3      ‎\n\nMerrell  ‎\n\nB07VFXC6T4       ‎\n\nJ066420  ...        None
# 4     ‎\n\nDesigual  ‎\n\nB08CN4MH5P          ‎\n\n9019  ...        None
#
#                                          breadcrumbs  \
# 0                          Shoes/Boys' Shoes/Sandals
# 1  Shoes/Women's Shoes/Fashion & Athletic Trainer...
# 2  Shoes/Women's Shoes/Fashion & Athletic Trainer...
# 3  Shoes/Women's Shoes/Fashion & Athletic Trainer...
# 4  Shoes/Women's Shoes/Fashion & Athletic Trainer...
#
#                                          images_list outer_material  \
# 0  [https://m.media-amazon.com/images/I/41Ouvqjha...      Synthetic
# 1  [https://m.media-amazon.com/images/I/416fCMuxw...         fabric
# 2  [https://m.media-amazon.com/images/I/31GuoIF6F...        Leather
# 3  [https://m.media-amazon.com/images/I/51bLpccQM...      Synthetic
# 4  [https://m.media-amazon.com/images/I/41nMmmxX-...      Polyester
#
#   inner_material       sole  closure    heel_height heel_type shoe_width
# 0      Synthetic     Rubber    Strap  2 centimetres      Flat     Medium
# 1           None     Rubber  Lace-Up           None   No Heel     medium
# 2           None    Leather  Lace-Up           None      None     Schmal
# 3        Manmade  Synthetic  Lace-Up           None      None     Medium
# 4      Synthetic     Rubber  Lace-Up           None      Flat     Medium
#
# [5 rows x 21 columns]

# %%
processed_df['title'].value_counts()
# Out:
# ARA Women's ROM Sneaker                                                                      11
# ARA Women's Osaka Sneaker                                                                     7
# HROYL Women/Girls' Professional Dance Shoes Salsa Ballroom Latin American Dance Shoes,213     6
# New Balance Men's 4040v5 Metal Baseball Cleat                                                 6
# mys Boys’ Chuck Taylor Hi-Top Slippers                                                        6
#                                                                                              ..
# Skechers - Womens Ghenter - Dagsby Shoe, Size:                                                1
# adidas Kids' Pro Spark 2018 Shoes                                                             1
# Geox Girl's J Piuma Bal.f Ballet Flat                                                         1
# PANTOFOLA D’ORO 1886 Men's League Low Oxford Flat                                             1
# viking Jolly Winter Rain Boot Child                                                           1
# Name: title, Length: 10618, dtype: int64

# %% [markdown]
# ### Removing unnecessary columns

# %%
# Remove 'url' and 'images_list' columns
processed_df.drop(columns=['url', 'images_list'], inplace=True)
# Remove '\n' and extra whitespaces from all string columns
processed_df = processed_df.apply(lambda x: x.str.strip() if x.dtype == 'object' else x)
processed_df = processed_df.apply(lambda x: x.str.replace('\n\n', '') if x.dtype == 'object' else x)

# Display the cleaned DataFrame
processed_df.head()
# Out:
#                                                title        asin  \
# 0  Geox Jr Sandal Strada B Fisherman, Brown Red, ...  B08BLP231K
# 1                    Fila Women's Oakmont Tr Sneaker  B08N587YZ9
# 2  Gabor Rollingsoft Trainers in Plus Sizes Beige...  B0918K4H1W
# 3  Merrell Women'S Bare Access Xtr Trail Running ...  B07KMB98CG
# 4  Desigual Women's Shoes_Runner_cmofl Sneakers W...  B08CN3S1ZK
#
#               price                    brand  \
# 0            £50.00     Visit the Geox Store
# 1  £49.57 - £234.95                     Fila
# 2              None                    Gabor
# 3  £67.00 - £182.44  Visit the Merrell Store
# 4   £38.96 - £81.10                 Desigual
#
#                         package_dimensions date_first_available  manufacturer  \
# 0        ‎31.2 x 21.4 x 11.4 cm; 820 Grams        ‎22 Jun. 2020         ‎Geox
# 1  ‎32.51 x 21.84 x 12.19 cm; 952.54 Grams         ‎6 Jun. 2020         ‎Fila
# 2                                      ‎No       ‎26 April 2021  ‎rollingsoft
# 3     ‎28.96 x 19.81 x 10.16 cm; 544 Grams        ‎20 Jan. 2020      ‎Merrell
# 4        ‎34.6 x 21.8 x 11.6 cm; 500 Grams        ‎13 July 2020     ‎Desigual
#
#    asin_number item_model_number country_of_origin department  \
# 0  ‎B08BLP231K      ‎J1524B02214          ‎Vietnam     ‎Boy's
# 1  ‎B089RQLYNW     ‎5JM00948-990          ‎Women's       None
# 2  ‎B0918K4H1W        ‎66.938-30          ‎Women's       None
# 3  ‎B07VFXC6T4          ‎J066420          ‎Women's       None
# 4  ‎B08CN4MH5P             ‎9019          ‎Women's       None
#
#                                          breadcrumbs outer_material  \
# 0                          Shoes/Boys' Shoes/Sandals      Synthetic
# 1  Shoes/Women's Shoes/Fashion & Athletic Trainer...         fabric
# 2  Shoes/Women's Shoes/Fashion & Athletic Trainer...        Leather
# 3  Shoes/Women's Shoes/Fashion & Athletic Trainer...      Synthetic
# 4  Shoes/Women's Shoes/Fashion & Athletic Trainer...      Polyester
#
#   inner_material       sole  closure    heel_height heel_type shoe_width
# 0      Synthetic     Rubber    Strap  2 centimetres      Flat     Medium
# 1           None     Rubber  Lace-Up           None   No Heel     medium
# 2           None    Leather  Lace-Up           None      None     Schmal
# 3        Manmade  Synthetic  Lace-Up           None      None     Medium
# 4      Synthetic     Rubber  Lace-Up           None      Flat     Medium

# %% [markdown]
# ### Information about the data

# %%
# Display basic information about the dataset
print("Shape of the dataset:", processed_df.shape)
print("\nColumns in the dataset:", processed_df.columns)
print("\nData types of columns:")
print(processed_df.dtypes)
# Out:
# Shape of the dataset: (11605, 19)
#
# Columns in the dataset: Index(['title', 'asin', 'price', 'brand', 'package_dimensions',
#        'date_first_available', 'manufacturer', 'asin_number',
#        'item_model_number', 'country_of_origin', 'department', 'breadcrumbs',
#        'outer_material', 'inner_material', 'sole', 'closure', 'heel_height',
#        'heel_type', 'shoe_width'],
#       dtype='object')
#
# Data types of columns:
# title                   object
# asin                    object
# price                   object
# brand                   object
# package_dimensions      object
# date_first_available    object
# manufacturer            object
# asin_number             object
# item_model_number       object
# country_of_origin       object
# department              object
# breadcrumbs             object
# outer_material          object
# inner_material          object
# sole                    object
# closure                 object
# heel_height             object
# heel_type               object
# shoe_width              object
# dtype: object

# %% [markdown]
# ### Handling extra columns

# %%
import numpy as np

# Convert 'price' column to string type to handle null values
processed_df['price'] = processed_df['price'].astype(str)

# Function to handle price conversion
def convert_price(price_str):
    if price_str.strip() == 'None':
        return np.nan
    price_list = price_str.split(' - ')
    if len(price_list) == 1:
        return float(price_list[0].replace('£', '').replace(',', ''))
    else:
        return (float(price_list[0].replace('£', '').replace(',', '')) + float(price_list[-1].replace('£', '').replace(',', ''))) / 2

# Apply function to 'price' column
processed_df['price'] = processed_df['price'].apply(convert_price)

# Remove non-ASCII characters and leading/trailing spaces from 'date_first_available' column
processed_df['date_first_available'] = processed_df['date_first_available'].str.replace(r'[^ -~]', '').str.strip()

# Replace invalid values with NaN
processed_df['date_first_available'] = processed_df['date_first_available'].replace(['None', 'V6471'], pd.NA)

# Convert 'date_first_available' to datetime
processed_df['date_first_available'] = pd.to_datetime(processed_df['date_first_available'], errors='coerce')
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_36728\3922608052.py:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   processed_df['date_first_available'] = processed_df['date_first_available'].str.replace(r'[^ -~]', '').str.strip()

# %%
print(processed_df.dtypes)
# Out:
# title                           object
# asin                            object
# price                          float64
# brand                           object
# package_dimensions              object
# date_first_available    datetime64[ns]
# manufacturer                    object
# asin_number                     object
# item_model_number               object
# country_of_origin               object
# department                      object
# breadcrumbs                     object
# outer_material                  object
# inner_material                  object
# sole                            object
# closure                         object
# heel_height                     object
# heel_type                       object
# shoe_width                      object
# dtype: object

# %%
# Check for missing values
print("\nMissing values:")
print(processed_df.isnull().sum())
# Out:
# Missing values:
# title                      0
# asin                       0
# price                    437
# brand                      0
# package_dimensions         0
# date_first_available    3563
# manufacturer             671
# asin_number              869
# item_model_number       1492
# country_of_origin       2805
# department              9924
# breadcrumbs                0
# outer_material          3042
# inner_material          5821
# sole                    1827
# closure                  943
# heel_height             8740
# heel_type               5435
# shoe_width              1164
# dtype: int64

# %% [markdown]
# ### Handling missing values

# %%
# Fill missing values
processed_df['price'].fillna(processed_df['price'].median(), inplace=True)
processed_df['date_first_available'].fillna(processed_df['date_first_available'].mode()[0], inplace=True)
processed_df['manufacturer'].fillna('Unknown', inplace=True)
processed_df['asin_number'].fillna('Unknown', inplace=True)
processed_df['item_model_number'].fillna('Unknown', inplace=True)
processed_df['country_of_origin'].fillna('Unknown', inplace=True)
processed_df['outer_material'].fillna('Unknown', inplace=True)
processed_df['inner_material'].fillna('Unknown', inplace=True)
processed_df['sole'].fillna('Unknown', inplace=True)
processed_df['closure'].fillna('Unknown', inplace=True)
processed_df['heel_height'].fillna('Unknown', inplace=True)
processed_df['heel_type'].fillna('Unknown', inplace=True)
processed_df['shoe_width'].fillna('Unknown', inplace=True)
processed_df['department'].fillna('Unknown', inplace=True)

# %% [markdown]
# ### Cleaned data

# %%
# Confirm missing values are handled
print("\nMissing values after handling:")
print(processed_df.isnull().sum())

# Display updated shape of the dataset
print("\nShape of the dataset after handling missing values:", processed_df.shape)
# Out:
# Missing values after handling:
# title                   0
# asin                    0
# price                   0
# brand                   0
# package_dimensions      0
# date_first_available    0
# manufacturer            0
# asin_number             0
# item_model_number       0
# country_of_origin       0
# department              0
# breadcrumbs             0
# outer_material          0
# inner_material          0
# sole                    0
# closure                 0
# heel_height             0
# heel_type               0
# shoe_width              0
# dtype: int64
#
# Shape of the dataset after handling missing values: (11605, 19)
